# %% [markdown]
# <a href="https://colab.research.google.com/github/rar8393/NLG_tests/blob/main/roberta_model_health_legal_finetune_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#https://github.com/huggingface/notebooks/blob/main/examples/language_modeling.ipynb

# %%
# !pip install datasets transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: datasets in /usr/local/lib/python3.7/dist-packages (2.6.0)
# Requirement already satisfied: transformers in /usr/local/lib/python3.7/dist-packages (4.23.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from datasets) (1.3.5)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.7/dist-packages (from datasets) (3.8.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from datasets) (1.21.6)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.7/dist-packages (from datasets) (2022.8.2)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.2.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (0.10.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from datasets) (6.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.7/dist-packages (from datasets) (4.64.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from datasets) (5.0.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.7/dist-packages (from datasets) (0.70.13)
# Requirement already satisfied: dill<0.3.6 in /usr/local/lib/python3.7/dist-packages (from datasets) (0.3.5.1)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (2.23.0)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.7/dist-packages (from datasets) (3.0.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from datasets) (21.3)
# Requirement already satisfied: responses<0.19 in /usr/local/lib/python3.7/dist-packages (from datasets) (0.18.0)
# Requirement already satisfied: pyarrow>=6.0.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (1.2.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (1.8.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (22.1.0)
# Requirement already satisfied: typing-extensions>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (4.1.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (6.0.2)
# Requirement already satisfied: asynctest==0.13.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (0.13.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (2.1.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.2.0->datasets) (3.8.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->datasets) (3.0.9)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (2022.9.24)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (1.25.11)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (3.0.4)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2022.6.2)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (0.13.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->datasets) (3.9.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets) (2022.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->datasets) (1.15.0)

# %%
import transformers

print(transformers.__version__)
# Out:
# 4.23.1

# %%
from datasets import load_dataset
legal_datasets = load_dataset("text", data_files={"train": 'legal_train.txt', "validation": 'legal_val.txt'})
health_datasets = load_dataset("text", data_files={"train": 'train.txt', "validation": 'val.txt'})
# Out:
# WARNING:datasets.builder:Using custom data configuration default-0cc7af0d97a37a44
# Downloading and preparing dataset text/default to /root/.cache/huggingface/datasets/text/default-0cc7af0d97a37a44/0.0.0/21a506d1b2b34316b1e82d0bd79066905d846e5d7e619823c0dd338d6f1fa6ad...
# Downloading data files:   0%|          | 0/2 [00:00<?, ?it/s]
# Extracting data files:   0%|          | 0/2 [00:00<?, ?it/s]
# 0 tables [00:00, ? tables/s]
# 0 tables [00:00, ? tables/s]
# Dataset text downloaded and prepared to /root/.cache/huggingface/datasets/text/default-0cc7af0d97a37a44/0.0.0/21a506d1b2b34316b1e82d0bd79066905d846e5d7e619823c0dd338d6f1fa6ad. Subsequent calls will reuse this data.
#   0%|          | 0/2 [00:00<?, ?it/s]
# WARNING:datasets.builder:Using custom data configuration default-a136af76aba7427b
# Downloading and preparing dataset text/default to /root/.cache/huggingface/datasets/text/default-a136af76aba7427b/0.0.0/21a506d1b2b34316b1e82d0bd79066905d846e5d7e619823c0dd338d6f1fa6ad...
# Downloading data files:   0%|          | 0/2 [00:00<?, ?it/s]
# Extracting data files:   0%|          | 0/2 [00:00<?, ?it/s]
# 0 tables [00:00, ? tables/s]
# 0 tables [00:00, ? tables/s]
# Dataset text downloaded and prepared to /root/.cache/huggingface/datasets/text/default-a136af76aba7427b/0.0.0/21a506d1b2b34316b1e82d0bd79066905d846e5d7e619823c0dd338d6f1fa6ad. Subsequent calls will reuse this data.
#   0%|          | 0/2 [00:00<?, ?it/s]

# %%
from datasets import ClassLabel
import random
import pandas as pd
from IPython.display import display, HTML

def show_random_elements(dataset, num_examples=10):
    assert num_examples <= len(dataset), "Can't pick more elements than there are in the dataset."
    picks = []
    for _ in range(num_examples):
        pick = random.randint(0, len(dataset)-1)
        while pick in picks:
            pick = random.randint(0, len(dataset)-1)
        picks.append(pick)
    
    df = pd.DataFrame(dataset[picks])
    for column, typ in dataset.features.items():
        if isinstance(typ, ClassLabel):
            df[column] = df[column].transform(lambda i: typ.names[i])
    display(HTML(df.to_html()))

# %%
#show_random_elements(datasets["train"])

# %%
#"facebook/opt-125m". "saibo/legal-roberta-base"
model_checkpoint = "roberta-base"

# %%
from transformers import AutoTokenizer
    
tokenizer = AutoTokenizer.from_pretrained(model_checkpoint, use_fast=True)
# Out:
# Could not locate the tokenizer configuration file, will try to use the model config instead.
# loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--roberta-base/snapshots/ff46155979338ff8063cdad90908b498ab91b181/config.json
# Model config RobertaConfig {
#   "_name_or_path": "roberta-base",
#   "architectures": [
#     "RobertaForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "roberta",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.23.1",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 50265
# }
#
# loading file vocab.json from cache at /root/.cache/huggingface/hub/models--roberta-base/snapshots/ff46155979338ff8063cdad90908b498ab91b181/vocab.json
# loading file merges.txt from cache at /root/.cache/huggingface/hub/models--roberta-base/snapshots/ff46155979338ff8063cdad90908b498ab91b181/merges.txt
# loading file tokenizer.json from cache at /root/.cache/huggingface/hub/models--roberta-base/snapshots/ff46155979338ff8063cdad90908b498ab91b181/tokenizer.json
# loading file added_tokens.json from cache at None
# loading file special_tokens_map.json from cache at None
# loading file tokenizer_config.json from cache at None
# loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--roberta-base/snapshots/ff46155979338ff8063cdad90908b498ab91b181/config.json
# Model config RobertaConfig {
#   "_name_or_path": "roberta-base",
#   "architectures": [
#     "RobertaForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "roberta",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.23.1",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 50265
# }

# %%
def tokenize_function(examples):
    return tokenizer(examples["text"])

# %%
legal_tokenized_datasets = legal_datasets.map(tokenize_function, batched=True, num_proc=4, remove_columns=["text"])
health_tokenized_datasets = health_datasets.map(tokenize_function, batched=True, num_proc=4, remove_columns=["text"])
# Out:
# #0:   0%|          | 0/7 [00:00<?, ?ba/s]
# #1:   0%|          | 0/7 [00:00<?, ?ba/s]
# #2:   0%|          | 0/7 [00:00<?, ?ba/s]
# #3:   0%|          | 0/7 [00:00<?, ?ba/s]
# Token indices sequence length is longer than the specified maximum sequence length for this model (530 > 512). Running this sequence through the model will result in indexing errors
# Token indices sequence length is longer than the specified maximum sequence length for this model (714 > 512). Running this sequence through the model will result in indexing errors
# Token indices sequence length is longer than the specified maximum sequence length for this model (724 > 512). Running this sequence through the model will result in indexing errors
# Token indices sequence length is longer than the specified maximum sequence length for this model (546 > 512). Running this sequence through the model will result in indexing errors
# #0:   0%|          | 0/2 [00:00<?, ?ba/s]
# #1:   0%|          | 0/2 [00:00<?, ?ba/s]
# #3:   0%|          | 0/2 [00:00<?, ?ba/s]
# #2:   0%|          | 0/2 [00:00<?, ?ba/s]
# Token indices sequence length is longer than the specified maximum sequence length for this model (574 > 512). Running this sequence through the model will result in indexing errors
# Token indices sequence length is longer than the specified maximum sequence length for this model (678 > 512). Running this sequence through the model will result in indexing errors
# Token indices sequence length is longer than the specified maximum sequence length for this model (561 > 512). Running this sequence through the model will result in indexing errors
# Token indices sequence length is longer than the specified maximum sequence length for this model (561 > 512). Running this sequence through the model will result in indexing errors
# #0:   0%|          | 0/2 [00:00<?, ?ba/s]
# #3:   0%|          | 0/2 [00:00<?, ?ba/s]
# #2:   0%|          | 0/2 [00:00<?, ?ba/s]
# #1:   0%|          | 0/2 [00:00<?, ?ba/s]
# Token indices sequence length is longer than the specified maximum sequence length for this model (2429 > 512). Running this sequence through the model will result in indexing errors
# Token indices sequence length is longer than the specified maximum sequence length for this model (1413 > 512). Running this sequence through the model will result in indexing errors
# Token indices sequence length is longer than the specified maximum sequence length for this model (1010 > 512). Running this sequence through the model will result in indexing errors
# Token indices sequence length is longer than the specified maximum sequence length for this model (1443 > 512). Running this sequence through the model will result in indexing errors
# #0:   0%|          | 0/1 [00:00<?, ?ba/s]
# #1:   0%|          | 0/1 [00:00<?, ?ba/s]
# #2:   0%|          | 0/1 [00:00<?, ?ba/s]
# #3:   0%|          | 0/1 [00:00<?, ?ba/s]
# Token indices sequence length is longer than the specified maximum sequence length for this model (1061 > 512). Running this sequence through the model will result in indexing errors
# Token indices sequence length is longer than the specified maximum sequence length for this model (1317 > 512). Running this sequence through the model will result in indexing errors
# Token indices sequence length is longer than the specified maximum sequence length for this model (669 > 512). Running this sequence through the model will result in indexing errors
# Token indices sequence length is longer than the specified maximum sequence length for this model (694 > 512). Running this sequence through the model will result in indexing errors

# %%
# block_size = tokenizer.model_max_length
block_size = 512

# %%
def group_texts(examples):
    # Concatenate all texts.
    concatenated_examples = {k: sum(examples[k], []) for k in examples.keys()}
    total_length = len(concatenated_examples[list(examples.keys())[0]])
    # We drop the small remainder, we could add padding if the model supported it instead of this drop, you can
        # customize this part to your needs.
    total_length = (total_length // block_size) * block_size
    # Split by chunks of max_len.
    result = {
        k: [t[i : i + block_size] for i in range(0, total_length, block_size)]
        for k, t in concatenated_examples.items()
    }
    result["labels"] = result["input_ids"].copy()
    return result

# %%
legal_lm_datasets = legal_tokenized_datasets.map(
    group_texts,
    batched=True,
    batch_size=1000,
    num_proc=4,
)

haelth_lm_datasets = health_tokenized_datasets.map(
    group_texts,
    batched=True,
    batch_size=1000,
    num_proc=4,
)
# Out:
# #0:   0%|          | 0/7 [00:00<?, ?ba/s]
# #1:   0%|          | 0/7 [00:00<?, ?ba/s]
# #2:   0%|          | 0/7 [00:00<?, ?ba/s]
# #3:   0%|          | 0/7 [00:00<?, ?ba/s]
# #0:   0%|          | 0/2 [00:00<?, ?ba/s]
# #1:   0%|          | 0/2 [00:00<?, ?ba/s]
# #2:   0%|          | 0/2 [00:00<?, ?ba/s]
# #3:   0%|          | 0/2 [00:00<?, ?ba/s]
# #0:   0%|          | 0/2 [00:00<?, ?ba/s]
# #1:   0%|          | 0/2 [00:00<?, ?ba/s]
# #2:   0%|          | 0/2 [00:00<?, ?ba/s]
# #3:   0%|          | 0/2 [00:00<?, ?ba/s]
# #0:   0%|          | 0/1 [00:00<?, ?ba/s]
# #1:   0%|          | 0/1 [00:00<?, ?ba/s]
# #3:   0%|          | 0/1 [00:00<?, ?ba/s]
# #2:   0%|          | 0/1 [00:00<?, ?ba/s]

# %%
from transformers import AutoModelForCausalLM
#If you want to use `RobertaLMHeadModel` as a standalone, add `is_decoder=True.`
model = AutoModelForCausalLM.from_pretrained(model_checkpoint, is_decoder=True)
# Out:
# loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--roberta-base/snapshots/ff46155979338ff8063cdad90908b498ab91b181/config.json
# Model config RobertaConfig {
#   "_name_or_path": "roberta-base",
#   "architectures": [
#     "RobertaForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "is_decoder": true,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "roberta",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.23.1",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 50265
# }
#
# loading weights file pytorch_model.bin from cache at /root/.cache/huggingface/hub/models--roberta-base/snapshots/ff46155979338ff8063cdad90908b498ab91b181/pytorch_model.bin
# All model checkpoint weights were used when initializing RobertaForCausalLM.
#
# All the weights of RobertaForCausalLM were initialized from the model checkpoint at roberta-base.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use RobertaForCausalLM for predictions without further training.

# %%
from transformers import Trainer, TrainingArguments

# %%
#https://stackoverflow.com/questions/72680734/huggingface-trainer-only-doing-3-epochs-no-matter-the-trainingarguments
model_name = model_checkpoint.split("/")[-1]
legal_training_args = TrainingArguments(
    f"{model_name}-legal-test",
    evaluation_strategy = "steps", #epoch
    num_train_epochs=3, 
    learning_rate=2e-5,
    weight_decay=0.01,
    push_to_hub=False,
    warmup_steps=1000,                # number of warmup steps for learning rate  
    save_steps=2000,
    eval_steps=500,
    save_total_limit=10,
    load_best_model_at_end= True,
    #output_dir='./results',
)
# Out:
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).

# %%
combo_training_args = TrainingArguments(
    f"{model_name}-combo-test",
    evaluation_strategy = "steps", #epoch
    num_train_epochs=5, 
    learning_rate=2e-5,
    weight_decay=0.01,
    push_to_hub=False,
    warmup_steps=1000,                # number of warmup steps for learning rate  
    save_steps=1500,
    eval_steps=500,
    save_total_limit=10,
    load_best_model_at_end= True,
    #output_dir='./results',
)
# Out:
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).

# %%
trainer = Trainer(
    model=model,
    args=legal_training_args,
    train_dataset=legal_lm_datasets["train"],
    eval_dataset=legal_lm_datasets["validation"],
)

# %%
trainer.train()
# Out:
# ***** Running training *****
#   Num examples = 13704
#   Num Epochs = 3
#   Instantaneous batch size per device = 8
#   Total train batch size (w. parallel, distributed & accumulation) = 8
#   Gradient Accumulation steps = 1
#   Total optimization steps = 5139
#     <div>
#
#       <progress value='5139' max='5139' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [5139/5139 2:03:34, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>5.528200</td>
#       <td>3.841919</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>3.779800</td>
#       <td>3.352776</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>3.429200</td>
#       <td>3.143784</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>3.240100</td>
#       <td>3.038590</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>3.149800</td>
#       <td>2.971355</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>3.083000</td>
#       <td>2.924944</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>3.032600</td>
#       <td>2.887908</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>2.971300</td>
#       <td>2.867745</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>2.957400</td>
#       <td>2.851317</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>2.950800</td>
#       <td>2.843137</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 2402
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 2402
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 2402
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 2402
#   Batch size = 8
# Saving model checkpoint to roberta-base-legal-test/checkpoint-2000
# Configuration saved in roberta-base-legal-test/checkpoint-2000/config.json
# Model weights saved in roberta-base-legal-test/checkpoint-2000/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 2402
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 2402
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 2402
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 2402
#   Batch size = 8
# Saving model checkpoint to roberta-base-legal-test/checkpoint-4000
# Configuration saved in roberta-base-legal-test/checkpoint-4000/config.json
# Model weights saved in roberta-base-legal-test/checkpoint-4000/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 2402
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 2402
#   Batch size = 8
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from roberta-base-legal-test/checkpoint-4000 (score: 2.8677453994750977).
# TrainOutput(global_step=5139, training_loss=3.4001980596164896, metrics={'train_runtime': 7415.3049, 'train_samples_per_second': 5.544, 'train_steps_per_second': 0.693, 'total_flos': 1.0823369727025152e+16, 'train_loss': 3.4001980596164896, 'epoch': 3.0})

# %%
from transformers import AutoModelForCausalLM

model = AutoModelForCausalLM.from_pretrained("roberta-base-legal-test/checkpoint-4000")

# %%
trainer = Trainer(
    model=model,
    args=combo_training_args,
    train_dataset=haelth_lm_datasets["train"],
    eval_dataset=haelth_lm_datasets["validation"],
)

# %%
trainer.train()
# Out:
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ***** Running training *****
#   Num examples = 8178
#   Num Epochs = 5
#   Instantaneous batch size per device = 8
#   Total train batch size (w. parallel, distributed & accumulation) = 8
#   Gradient Accumulation steps = 1
#   Total optimization steps = 5115
#     <div>
#
#       <progress value='4341' max='5115' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [4341/5115 1:34:47 < 16:54, 0.76 it/s, Epoch 4.24/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>3.904700</td>
#       <td>3.456605</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>3.524100</td>
#       <td>3.235470</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>3.296100</td>
#       <td>3.117704</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>3.196600</td>
#       <td>3.042534</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>3.085000</td>
#       <td>3.001623</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>3.053000</td>
#       <td>2.969491</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>2.983200</td>
#       <td>2.952484</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>2.975500</td>
#       <td>2.933725</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 1097
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1097
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1097
#   Batch size = 8
# Saving model checkpoint to roberta-base-combo-test/checkpoint-1500
# Configuration saved in roberta-base-combo-test/checkpoint-1500/config.json
# Model weights saved in roberta-base-combo-test/checkpoint-1500/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 1097
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1097
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1097
#   Batch size = 8
# Saving model checkpoint to roberta-base-combo-test/checkpoint-3000
# Configuration saved in roberta-base-combo-test/checkpoint-3000/config.json
# Model weights saved in roberta-base-combo-test/checkpoint-3000/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 1097
#   Batch size = 8
# ***** Running Evaluation *****
#   Num examples = 1097
#   Batch size = 8
#     <div>
#
#       <progress value='4521' max='5115' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [4521/5115 1:39:24 < 13:04, 0.76 it/s, Epoch 4.42/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>3.904700</td>
#       <td>3.456605</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>3.524100</td>
#       <td>3.235470</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>3.296100</td>
#       <td>3.117704</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>3.196600</td>
#       <td>3.042534</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>3.085000</td>
#       <td>3.001623</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>3.053000</td>
#       <td>2.969491</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>2.983200</td>
#       <td>2.952484</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>2.975500</td>
#       <td>2.933725</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>2.919100</td>
#       <td>2.925078</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 1097
#   Batch size = 8
# Saving model checkpoint to roberta-base-combo-test/checkpoint-4500
# Configuration saved in roberta-base-combo-test/checkpoint-4500/config.json
# Model weights saved in roberta-base-combo-test/checkpoint-4500/pytorch_model.bin
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-48-3435b262f1ae> in <module>
# ----> 1 trainer.train()
#
# /usr/local/lib/python3.7/dist-packages/transformers/trainer.py in train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    1502             resume_from_checkpoint=resume_from_checkpoint,
#    1503             trial=trial,
# -> 1504             ignore_keys_for_eval=ignore_keys_for_eval,
#    1505         )
#    1506
#
# /usr/local/lib/python3.7/dist-packages/transformers/trainer.py in _inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    1740                         tr_loss_step = self.training_step(model, inputs)
#    1741                 else:
# -> 1742                     tr_loss_step = self.training_step(model, inputs)
#    1743
#    1744                 if (
#
# /usr/local/lib/python3.7/dist-packages/transformers/trainer.py in training_step(self, model, inputs)
#    2502             loss = self.deepspeed.backward(loss)
#    2503         else:
# -> 2504             loss.backward()
#    2505
#    2506         return loss.detach()
#
# /usr/local/lib/python3.7/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     394                 create_graph=create_graph,
#     395                 inputs=inputs)
# --> 396         torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#     397
#     398     def register_hook(self, hook):
#
# /usr/local/lib/python3.7/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     173     Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     174         tensors, grad_tensors_, retain_graph, create_graph, inputs,
# --> 175         allow_unreachable=True, accumulate_grad=True)  # Calls into the C++ engine to run the backward pass
#     176
#     177 def grad(
#
# KeyboardInterrupt:

# %%
model = AutoModelForCausalLM.from_pretrained("roberta-base-combo-test/checkpoint-4500")
# Out:
# loading configuration file roberta-base-combo-test/checkpoint-4500/config.json
# Model config RobertaConfig {
#   "_name_or_path": "roberta-base-combo-test/checkpoint-4500",
#   "architectures": [
#     "RobertaForCausalLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "is_decoder": true,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "roberta",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "torch_dtype": "float32",
#   "transformers_version": "4.23.1",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 50265
# }
#
# loading weights file roberta-base-combo-test/checkpoint-4500/pytorch_model.bin
# All model checkpoint weights were used when initializing RobertaForCausalLM.
#
# All the weights of RobertaForCausalLM were initialized from the model checkpoint at roberta-base-combo-test/checkpoint-4500.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use RobertaForCausalLM for predictions without further training.

# %%
import importlib
import generate_txt
importlib.reload(generate_txt)
generator = generate_txt.generate_model_results(tokenizer, model)

# %%
test_metrics_1 = generator.generate_sample("The event has a ", visualize=False)
# Out:
# /content/generated_text_metrics.py:52: UserWarning: [W007] The model you're using has no word vectors loaded, so the result of the Doc.similarity method will be based on the tagger, parser and NER, which may not give useful similarity judgements. This may happen if you're using one of the small models, e.g. `en_core_web_sm`, which don't ship with word vectors and only use context-sensitive tensors. You can always add your own word vectors, or use one of the larger models instead if available.
#   similarity.append(gen_doc.similarity(sent))
# /content/generated_text_metrics.py:54: UserWarning: [W007] The model you're using has no word vectors loaded, so the result of the Span.similarity method will be based on the tagger, parser and NER, which may not give useful similarity judgements. This may happen if you're using one of the small models, e.g. `en_core_web_sm`, which don't ship with word vectors and only use context-sensitive tensors. You can always add your own word vectors, or use one of the larger models instead if available.
#   similarity.append(sent.similarity(tmp))

# %%
for key in test_metrics_1.keys():
  print(key)
# Out:
# The event has a
# A new study in mice finds that, in most cases, people with Alzheimer’s disease have had a complete loss of memory. This suggests that age will help improve the development of brain tissue, and the process may start to play a role in early death. This conclusion raises new fears about Alzheimer’s
# Abstract A recent study has suggested that exposure to exposure to SARS-CoV-2 may affect the risk of lung failure and mortality. Finally, the study focused on the effects of exposure to airborne pathogens on the lung health and survival of patients with lung failure. However, researchers have not directly assessed the effects of
# Scientists, in their work from China, describe the process that causes the brain to contract, which may include abnormal cells and proteins. Some cells also develop damage to proteins. To combat the deterioration, doctors specialize in cancer and can develop specific types of cancer treatment. The treatment of cancer involves various therapies to help a person
# Coronavirus Disease 2019 (COVID-19) has spread worldwide globally. In the recent recent outbreak of severe acute respiratory syndrome coronavirus 2 (SARS-CoV-2) in Wuhan, Wuhan, the infection has spread to other populations. As the outbreak continues on,
# The emerging coronavirus disease 2019 (COVID-19) is the second-impact of the global respiratory disease with the highest rates of acute respiratory failure in the U.S. and other developing states. On March 10th, 2020, COVID-19 peaked in France, which was associated with an almost

# %%
for key in test_metrics_1.keys():
  print(test_metrics_1[key]['metric'])
# Out:
# {'number_ents': 0, 'ents': [], 'number_nouns': 1, 'nouns': ['event'], 'number_sents': 1, 'avg_sent_len': 4.0, 'sent_repeat_score': [0.0]}
# {'number_ents': 0, 'ents': [], 'number_nouns': 18, 'nouns': ['study', 'mouse', 'case', 'people', 'Alzheimer', 'disease', 'loss', 'memory', 'age', 'development', 'brain', 'tissue', 'process', 'role', 'death', 'conclusion', 'fear', 'Alzheimer'], 'number_sents': 3, 'avg_sent_len': 19.666666666666668, 'sent_repeat_score': [0.16000000000000003, 0.038461538461538436, 0.0]}
# {'number_ents': 0, 'ents': [], 'number_nouns': 22, 'nouns': ['Abstract', 'study', 'exposure', 'exposure', 'SARS', 'CoV-2', 'risk', 'lung', 'failure', 'mortality', 'study', 'effect', 'exposure', 'pathogen', 'lung', 'health', 'survival', 'patient', 'lung', 'failure', 'researcher', 'effect'], 'number_sents': 3, 'avg_sent_len': 19.666666666666668, 'sent_repeat_score': [0.08333333333333337, 0.19999999999999996, 0.0]}
# {'number_ents': 1, 'ents': [China], 'number_nouns': 21, 'nouns': ['scientist', 'work', 'China', 'process', 'brain', 'contract', 'cell', 'protein', 'cell', 'damage', 'protein', 'deterioration', 'doctor', 'cancer', 'type', 'cancer', 'treatment', 'treatment', 'cancer', 'therapy', 'person'], 'number_sents': 4, 'avg_sent_len': 15.75, 'sent_repeat_score': [0.11538461538461542, 0.0, 0.05555555555555558, 0.0]}
# {'number_ents': 3, 'ents': [2019, Wuhan, Wuhan], 'number_nouns': 12, 'nouns': ['Coronavirus', 'Disease', 'COVID-19', 'outbreak', 'syndrome', 'coronavirus', 'SARS', 'Wuhan', 'Wuhan', 'infection', 'population', 'outbreak'], 'number_sents': 3, 'avg_sent_len': 15.666666666666666, 'sent_repeat_score': [0.0, 0.16666666666666663, 0.0]}
# {'number_ents': 5, 'ents': [2019, second, U.S., March 10th, 2020, France], 'number_nouns': 13, 'nouns': ['coronavirus', 'disease', 'COVID-19', 'impact', 'disease', 'rate', 'failure', 'U.S.', 'state', 'March', '10th', 'COVID-19', 'France'], 'number_sents': 2, 'avg_sent_len': 25.5, 'sent_repeat_score': [0.20588235294117652, 0.11764705882352944]}

# %%
print('Number named entities, number nouns, number of sentences, avg sentence length, repeat score')
for key in test_metrics_1.keys():
  print(test_metrics_1[key]['metric']['number_ents'], test_metrics_1[key]['metric']['number_nouns'],
        test_metrics_1[key]['metric']['number_sents'],  test_metrics_1[key]['metric']['avg_sent_len'],
        test_metrics_1[key]['metric']['sent_repeat_score'])
# Out:
# Number named entities, number nouns, number of sentences, avg sentence length, repeat score
# 0 1 1 4.0 [0.0]
# 0 18 3 19.666666666666668 [0.16000000000000003, 0.038461538461538436, 0.0]
# 0 22 3 19.666666666666668 [0.08333333333333337, 0.19999999999999996, 0.0]
# 1 21 4 15.75 [0.11538461538461542, 0.0, 0.05555555555555558, 0.0]
# 3 12 3 15.666666666666666 [0.0, 0.16666666666666663, 0.0]
# 5 13 2 25.5 [0.20588235294117652, 0.11764705882352944]

# %%
test_metrics_2 = generator.generate_sample("The conference started with a ", visualize=False)

# %%
for key in test_metrics_2.keys():
  print(key)
# Out:
# The conference started with a
# We consider the hypothesis that there remains time to collect data on the transmission dynamics of the novel coronavirus. The main issue is that no data on the transmission dynamics of the novel coronavirus have been collected until 20th April 2020. Findings: A multivariable analysis of the data of a total of
# Introduction: The novel coronavirus, caused by SARS-CoV-2, emerged in Wuhan, China but recently emerged. Now, SARS-CoV-2 has spread worldwide. The recent development of this virus has prompted experts to report on the spread of it. This study is aimed
# The COVID-19 pandemic has caused thousands of deaths worldwide and caused thousands to develop severe respiratory problems. We developed an epidemiological model to simulate the impact of a severe respiratory illness and the incidence on the disease, including death. The model is calibrated to fit the age of the individuals in the study compared to
# To prevent the development of Covid-19, a small hospital, which uses a single-step oxygen chamber, has taken a different approach. This technique works by providing a single person with oxygen levels equal to three levels. In an emergency environment that requires hospital staff, Covid-19 is extremely congested.
# The global coronavirus season (COVID-19) has spread nationwide through the Wuhan province, China. In addition to the severe COVID-19 cases, the first deaths were reported in the surrounding region, causing the world to fear more. However, countries experiencing more than one year, the number

# %%
for key in test_metrics_2.keys():
  print(test_metrics_2[key]['metric'])
# Out:
# {'number_ents': 0, 'ents': [], 'number_nouns': 1, 'nouns': ['conference'], 'number_sents': 1, 'avg_sent_len': 5.0, 'sent_repeat_score': [0.0]}
# {'number_ents': 1, 'ents': [20th April 2020], 'number_nouns': 16, 'nouns': ['hypothesis', 'time', 'datum', 'transmission', 'dynamic', 'coronavirus', 'issue', 'datum', 'transmission', 'dynamic', 'coronavirus', 'April', 'finding', 'analysis', 'datum', 'total'], 'number_sents': 4, 'avg_sent_len': 13.75, 'sent_repeat_score': [0.09999999999999998, 0.13043478260869568, 0.0, 0.30000000000000004]}
# {'number_ents': 2, 'ents': [Wuhan, China], 'number_nouns': 13, 'nouns': ['introduction', 'coronavirus', 'SARS', 'CoV-2', 'Wuhan', 'China', 'SARS', 'CoV-2', 'development', 'virus', 'expert', 'spread', 'study'], 'number_sents': 4, 'avg_sent_len': 12.75, 'sent_repeat_score': [0.1428571428571429, 0.0, 0.11764705882352944, 0.0]}
# {'number_ents': 2, 'ents': [thousands, thousands], 'number_nouns': 16, 'nouns': ['covid-19', 'pandemic', 'thousand', 'death', 'thousand', 'problem', 'model', 'impact', 'illness', 'incidence', 'disease', 'death', 'model', 'age', 'individual', 'study'], 'number_sents': 3, 'avg_sent_len': 19.333333333333332, 'sent_repeat_score': [0.11111111111111116, 0.08333333333333337, 0.25]}
# {'number_ents': 1, 'ents': [three], 'number_nouns': 17, 'nouns': ['development', 'Covid-19', 'hospital', 'step', 'oxygen', 'chamber', 'approach', 'technique', 'person', 'oxygen', 'level', 'level', 'emergency', 'environment', 'hospital', 'staff', 'Covid-19'], 'number_sents': 3, 'avg_sent_len': 18.666666666666668, 'sent_repeat_score': [0.15384615384615385, 0.0625, 0.0]}
# {'number_ents': 4, 'ents': [Wuhan, China, first, more than one year], 'number_nouns': 14, 'nouns': ['coronavirus', 'season', 'Wuhan', 'province', 'China', 'addition', 'covid-19', 'case', 'death', 'region', 'world', 'country', 'year', 'number'], 'number_sents': 3, 'avg_sent_len': 17.666666666666668, 'sent_repeat_score': [0.05882352941176472, 0.24, 0.09090909090909094]}

# %%
print('Number named entities, number nouns, number of sentences, avg sentence length, repeat score')
for key in test_metrics_2.keys():
  print(test_metrics_2[key]['metric']['number_ents'], test_metrics_2[key]['metric']['number_nouns'],
        test_metrics_2[key]['metric']['number_sents'],  test_metrics_2[key]['metric']['avg_sent_len'],
        test_metrics_2[key]['metric']['sent_repeat_score'])
# Out:
# Number named entities, number nouns, number of sentences, avg sentence length, repeat score
# 0 1 1 5.0 [0.0]
# 1 16 4 13.75 [0.09999999999999998, 0.13043478260869568, 0.0, 0.30000000000000004]
# 2 13 4 12.75 [0.1428571428571429, 0.0, 0.11764705882352944, 0.0]
# 2 16 3 19.333333333333332 [0.11111111111111116, 0.08333333333333337, 0.25]
# 1 17 3 18.666666666666668 [0.15384615384615385, 0.0625, 0.0]
# 4 14 3 17.666666666666668 [0.05882352941176472, 0.24, 0.09090909090909094]

# %%
#event_txt = 'Calling All Climate Warriors! Youth for Climate Justice is hosting a series of webinars where we feature three climate justice-focused initiatives spearheaded by young community organizers. Discover local movements in your community, learn about effective ways to communicate with legislators and lead the charge in climate justice! '
sick_txt = 'The flu was really bad this year. Please prepare for the conference accordinly, vaccines are available. This will '

# %%
test_metrics_3 = generator.generate_sample(sick_txt, visualize=False)

# %%
for key in test_metrics_3.keys():
  print(key)
# Out:
# The flu was really bad this year. Please prepare for the conference accordinly, vaccines are available. This will
# Background: We report the systematic review of the current COVID 19 pandemic and find that the use of certain immunogenic measures remains challenging since pandemic outbreak began. However, SARS-CoV-2-infected patients are still more aggressive than in its current pandemic. We explored the prevalence of immun
# In this paper, we attempt to understand the epidemiological effects of viral load of COVID-19 among all Asian people. In addition, we examine the clinical characteristics of the infected patients in various countries around the world. We present the basic epidemiological characteristics and diagnoses of patients with COVID-19 from a wide
# A blood study that aims to provide a more accurate diagnosis of leukemia, or cancer, may help to understand the role of inflammation in anemia. Researchers who now know how to treat leukemia have been using an autoimmune disorder called leukemotsia, a common autoimmune disorder. It causes symptoms such as headaches and short
# Background: Understanding how a person develops the infection that causes the SARS-CoV-2 virus continues to provide additional information for doctors and other healthcare professionals. Using data from imported cases of COVID-19 and confirmed deaths have helped identify the disease most severe. Methods: In order to measure the effects of the
# A coronavirus is the most serious cause of severe acute respiratory syndrome coronavirus 2 (SARS-CoV-2), caused by a new coronavirus. Finally, we investigated the effect of the ACE2 receptor on human immune responses worldwide. We used the ACE2 expression and binding domain of S

# %%
for key in test_metrics_3.keys():
  print(test_metrics_3[key]['metric'])
# Out:
# {'number_ents': 1, 'ents': [this year], 'number_nouns': 4, 'nouns': ['flu', 'year', 'conference', 'vaccine'], 'number_sents': 3, 'avg_sent_len': 7.0, 'sent_repeat_score': [0.0, 0.0, 0.0]}
# {'number_ents': 0, 'ents': [], 'number_nouns': 12, 'nouns': ['background', 'review', 'COVID', 'use', 'measure', 'outbreak', 'SARS', 'CoV-2', 'patient', 'pandemic', 'prevalence', 'immun'], 'number_sents': 3, 'avg_sent_len': 17.666666666666668, 'sent_repeat_score': [0.13793103448275867, 0.05555555555555558, 0.0]}
# {'number_ents': 1, 'ents': [Asian], 'number_nouns': 14, 'nouns': ['paper', 'effect', 'load', 'covid-19', 'people', 'addition', 'characteristic', 'patient', 'country', 'world', 'characteristic', 'diagnosis', 'patient', 'covid-19'], 'number_sents': 3, 'avg_sent_len': 18.333333333333332, 'sent_repeat_score': [0.04761904761904767, 0.1578947368421053, 0.0]}
# {'number_ents': 1, 'ents': [leukemotsia], 'number_nouns': 15, 'nouns': ['blood', 'study', 'diagnosis', 'leukemia', 'cancer', 'role', 'inflammation', 'anemia', 'researcher', 'leukemia', 'disorder', 'leukemotsia', 'disorder', 'symptom', 'headache'], 'number_sents': 3, 'avg_sent_len': 19.333333333333332, 'sent_repeat_score': [0.1428571428571429, 0.09090909090909094, 0.0]}
# {'number_ents': 0, 'ents': [], 'number_nouns': 18, 'nouns': ['background', 'person', 'infection', 'SARS', 'CoV-2', 'virus', 'information', 'doctor', 'healthcare', 'professional', 'datum', 'case', 'covid-19', 'death', 'disease', 'method', 'order', 'effect'], 'number_sents': 4, 'avg_sent_len': 14.0, 'sent_repeat_score': [0.0357142857142857, 0.0, 0.0, 0.125]}
# {'number_ents': 1, 'ents': [S], 'number_nouns': 14, 'nouns': ['coronavirus', 'cause', 'syndrome', 'coronavirus', 'SARS', 'coronavirus', 'effect', 'ACE2', 'receptor', 'response', 'ACE2', 'expression', 'domain', 'S'], 'number_sents': 3, 'avg_sent_len': 17.333333333333332, 'sent_repeat_score': [0.15384615384615385, 0.0625, 0.0]}

# %%
print('Number named entities, number nouns, number of sentences, avg sentence length, repeat score')
for key in test_metrics_3.keys():
  print(test_metrics_3[key]['metric']['number_ents'], test_metrics_3[key]['metric']['number_nouns'],
        test_metrics_3[key]['metric']['number_sents'],  test_metrics_3[key]['metric']['avg_sent_len'],
        test_metrics_3[key]['metric']['sent_repeat_score'])
# Out:
# Number named entities, number nouns, number of sentences, avg sentence length, repeat score
# 1 4 3 7.0 [0.0, 0.0, 0.0]
# 0 12 3 17.666666666666668 [0.13793103448275867, 0.05555555555555558, 0.0]
# 1 14 3 18.333333333333332 [0.04761904761904767, 0.1578947368421053, 0.0]
# 1 15 3 19.333333333333332 [0.1428571428571429, 0.09090909090909094, 0.0]
# 0 18 4 14.0 [0.0357142857142857, 0.0, 0.0, 0.125]
# 1 14 3 17.333333333333332 [0.15384615384615385, 0.0625, 0.0]

# %%
event_txt = 'Calling All Climate Warriors! Youth for Climate Justice is hosting a series of webinars where we feature three climate justice-focused initiatives spearheaded by young community organizers. Discover local movements in your community, learn about effective ways to communicate with legislators and lead the charge in climate justice! '
sick_txt = 'The flu was really bad this year. Please prepare for the conference accordinly, vaccines are available. This will '
#generator2(event_txt + sick_txt)
combo = event_txt + sick_txt

# %%
test_metrics_4 = generator.generate_sample(combo, visualize=False)

# %%
for key in test_metrics_4.keys():
  print(key)
# Out:
# Calling All Climate Warriors! Youth for Climate Justice is hosting a series of webinars where we feature three climate justice-focused initiatives spearheaded by young community organizers. Discover local movements in your community, learn about effective ways to communicate with legislators and lead the charge in climate justice! The flu was really bad this year. Please prepare for the conference accordinly, vaccines are available. This will
# Background: SARS-CoV-2 is an infectious disease. Rapid global infectious disease response requires massive efforts to curb this pandemic. First-line response is to identify the infectious infectious group and the control strategies to determine the best way to treat future infectious outbreaks. This study aimed to explore the potential differences between
# If you buy something through a link on this page, we may earn a small commission. How this works. A 2019 novel coronavirus (2019-nCoV-2) has spread across Europe, affecting more than 180 million people in the United States. Our analysis has identified different characteristics of the virus throughout
# Mucaria can be contagious, causing small or severe respiratory symptoms and potentially infectious diseases. There are two main types of mucaria: a type of mucaria, an acute-symptomatic. The mucaria typically affects respiratory tract tract pain pain and cough. The symptoms of mucaria occur
# COVID-19 has been declared an pandemic worldwide that is causing more than 480 million people, with the estimated number of death caused by COVID-19. Methods Method We generated a single-stream dataset of all Chinese Hubei Province Residents's information on the number of COVID-19 cases and died
# Severe acute respiratory syndrome coronavirus 2 (SARS-CoV-2) is causing death in the United States. The most prevalent respiratory syndrome is Coronavirus Disease 2019 (COVID-19). Among people with severe acute respiratory syndrome, the risk of death is significantly higher in people with or

# %%
for key in test_metrics_4.keys():
  print(test_metrics_4[key]['metric'])
# Out:
# {'number_ents': 2, 'ents': [three, this year], 'number_nouns': 23, 'nouns': ['Climate', 'Warriors', 'youth', 'Climate', 'Justice', 'series', 'webinar', 'climate', 'justice', 'initiative', 'community', 'organizer', 'movement', 'community', 'way', 'legislator', 'charge', 'climate', 'justice', 'flu', 'year', 'conference', 'vaccine'], 'number_sents': 6, 'avg_sent_len': 12.333333333333334, 'sent_repeat_score': [0.0, 0.0, 0.04347826086956519, 0.0, 0.0, 0.0]}
# {'number_ents': 1, 'ents': [First], 'number_nouns': 16, 'nouns': ['background', 'SARS', 'CoV-2', 'disease', 'disease', 'response', 'effort', 'line', 'response', 'group', 'control', 'strategy', 'way', 'outbreak', 'study', 'difference'], 'number_sents': 4, 'avg_sent_len': 14.5, 'sent_repeat_score': [0.0, 0.0, 0.23076923076923073, 0.0]}
# {'number_ents': 5, 'ents': [2019, 2019, Europe, more than 180 million, the United States], 'number_nouns': 12, 'nouns': ['link', 'page', 'commission', 'coronavirus', 'ncov-2', 'Europe', 'people', 'United', 'States', 'analysis', 'characteristic', 'virus'], 'number_sents': 4, 'avg_sent_len': 14.25, 'sent_repeat_score': [0.05555555555555558, 0.0, 0.040000000000000036, 0.0]}
# {'number_ents': 2, 'ents': [Mucaria, two], 'number_nouns': 16, 'nouns': ['Mucaria', 'symptom', 'disease', 'type', 'mucaria', 'type', 'mucaria', 'acute', 'mucaria', 'tract', 'tract', 'pain', 'pain', 'cough', 'symptom', 'mucaria'], 'number_sents': 4, 'avg_sent_len': 12.75, 'sent_repeat_score': [0.0, 0.16666666666666663, 0.16666666666666663, 0.0]}
# {'number_ents': 2, 'ents': [more than 480 million, Chinese], 'number_nouns': 18, 'nouns': ['COVID-19', 'pandemic', 'people', 'number', 'death', 'covid-19', 'method', 'Method', 'stream', 'dataset', 'Chinese', 'Hubei', 'Province', 'Residents', 'information', 'number', 'covid-19', 'case'], 'number_sents': 2, 'avg_sent_len': 25.5, 'sent_repeat_score': [0.07692307692307687, 0.040000000000000036]}
# {'number_ents': 3, 'ents': [the United States, Coronavirus Disease, 2019], 'number_nouns': 16, 'nouns': ['syndrome', 'coronavirus', 'SARS', 'CoV-2', 'death', 'United', 'States', 'syndrome', 'Coronavirus', 'Disease', 'COVID-19', 'people', 'syndrome', 'risk', 'death', 'people'], 'number_sents': 3, 'avg_sent_len': 17.0, 'sent_repeat_score': [0.0, 0.0, 0.10526315789473684]}

# %%
print('Number named entities, number nouns, number of sentences, avg sentence length, repeat score')
for key in test_metrics_4.keys():
  metric_load = test_metrics_4[key]['metric']
  print(metric_load['number_ents'], metric_load['number_nouns'],
        metric_load['number_sents'],  metric_load['avg_sent_len'],
        metric_load['sent_repeat_score'])
# Out:
# Number named entities, number nouns, number of sentences, avg sentence length, repeat score
# 2 23 6 12.333333333333334 [0.0, 0.0, 0.04347826086956519, 0.0, 0.0, 0.0]
# 1 16 4 14.5 [0.0, 0.0, 0.23076923076923073, 0.0]
# 5 12 4 14.25 [0.05555555555555558, 0.0, 0.040000000000000036, 0.0]
# 2 16 4 12.75 [0.0, 0.16666666666666663, 0.16666666666666663, 0.0]
# 2 18 2 25.5 [0.07692307692307687, 0.040000000000000036]
# 3 16 3 17.0 [0.0, 0.0, 0.10526315789473684]

# %%
#check different lengths
length_metric_1 = generator.generate_sample(sick_txt, max_length=32, visualize=False)
length_metric_2 = generator.generate_sample(sick_txt, max_length=64, visualize=False)
length_metric_3 = generator.generate_sample(sick_txt, max_length=128, visualize=False)

# %%
for key in length_metric_1.keys():
  print(key)
  print(len(key))
# Out:
# The flu was really bad this year. Please prepare for the conference accordinly, vaccines are available. This will
# 114
# Background: The rapid emergence of Coronavirus Disease 2019 (COVID-19) has posed great challenges to public healthcare practitioners. Findings: We
# 146
# The coronaviruses were first identified on 7 of March 2020, while there has been no definitive case of COVID-19. We analyzed the genome
# 135
#
# 0
# Importance What comes out of the recent coronavirus pandemic?The disease has caused more than 1 million deaths, but it has not yet been directly
# 144

# %%
for key in length_metric_1.keys():
  print(length_metric_1[key]['metric'])
# Out:
# {'number_ents': 1, 'ents': [this year], 'number_nouns': 4, 'nouns': ['flu', 'year', 'conference', 'vaccine'], 'number_sents': 3, 'avg_sent_len': 7.0, 'sent_repeat_score': [0.0, 0.0, 0.0]}
# {'number_ents': 2, 'ents': [Coronavirus Disease, 2019], 'number_nouns': 9, 'nouns': ['background', 'emergence', 'Coronavirus', 'Disease', 'COVID-19', 'challenge', 'healthcare', 'practitioner', 'finding'], 'number_sents': 3, 'avg_sent_len': 8.0, 'sent_repeat_score': [0.0, 0.0, 0.0]}
# {'number_ents': 2, 'ents': [first, 7 of March 2020], 'number_nouns': 5, 'nouns': ['coronaviruse', 'March', 'case', 'covid-19', 'genome'], 'number_sents': 2, 'avg_sent_len': 12.5, 'sent_repeat_score': [0.09523809523809523, 0.0]}
# {'number_ents': 0, 'ents': [], 'number_nouns': 0, 'nouns': [], 'number_sents': 0, 'avg_sent_len': 0.0, 'sent_repeat_score': []}
# {'number_ents': 1, 'ents': [more than 1 million], 'number_nouns': 5, 'nouns': ['importance', 'coronavirus', 'pandemic?the', 'disease', 'death'], 'number_sents': 1, 'avg_sent_len': 25.0, 'sent_repeat_score': [0.040000000000000036]}

# %%
print('Number named entities, number nouns, number of sentences, avg sentence length, repeat score')
for key in length_metric_1.keys():
  metric_load = length_metric_1[key]['metric']
  print(metric_load['number_ents'], metric_load['number_nouns'],
        metric_load['number_sents'],  metric_load['avg_sent_len'],
        metric_load['sent_repeat_score'])
# Out:
# Number named entities, number nouns, number of sentences, avg sentence length, repeat score
# 1 4 3 7.0 [0.0, 0.0, 0.0]
# 2 9 3 8.0 [0.0, 0.0, 0.0]
# 2 5 2 12.5 [0.09523809523809523, 0.0]
# 0 0 0 0.0 []
# 1 5 1 25.0 [0.040000000000000036]

# %%
for key in length_metric_2.keys():
  print(key)
# Out:
# The flu was really bad this year. Please prepare for the conference accordinly, vaccines are available. This will
# Scientists have found that mice should not be exposed to flu viruses as large as 100 g of influenza virus in a single lung or as much as 100 g of flu fluid. A study reports a new study on mouse brains. Researchers have found that mice should not inhale the virus. The researchers found that mice who exposed
# Objective: To investigate the clinical characteristics of SARS-CoV-2 RNA in human cases. Results: The incidence of viral RNA in a positive-positive patients showed high heterogeneity in positive cases and viral RNA in negative patients. Our clinical and biochemical features of both positive-negative patients and negative cases demonstrated strong
# The COVID-19 pandemic has caused a plethora of challenges in countries with limited financial resources. The virus has infected over 50 million individuals worldwide and is a pandemic that continues to disrupt economic activity, social mobility and health services. The world has been hit, especially by the COVID-19 pandemic.
# If you buy something through a link on this page, we may earn a small commission. We may earn a small commission. How this works. The body does not respond to heat when a person is in hot, but a cold or flu is associated with a more severe condition. It cannot respond to heat, cold
# Coronavirus disease 2019 (COVID-19) is becoming global disease, with more than 220000 confirmed cases and more than 150 million deaths worldwide. In early 2018, the first clinical trial completed the clinical trial in the United Kingdom and China, completed which included 9,000 participants in the first cohort.

# %%
for key in length_metric_2.keys():
    print(key)
    print(len(key))
# Out:
# The flu was really bad this year. Please prepare for the conference accordinly, vaccines are available. This will
# 114
# Scientists have found that mice should not be exposed to flu viruses as large as 100 g of influenza virus in a single lung or as much as 100 g of flu fluid. A study reports a new study on mouse brains. Researchers have found that mice should not inhale the virus. The researchers found that mice who exposed
# 307
# Objective: To investigate the clinical characteristics of SARS-CoV-2 RNA in human cases. Results: The incidence of viral RNA in a positive-positive patients showed high heterogeneity in positive cases and viral RNA in negative patients. Our clinical and biochemical features of both positive-negative patients and negative cases demonstrated strong
# 348
# The COVID-19 pandemic has caused a plethora of challenges in countries with limited financial resources. The virus has infected over 50 million individuals worldwide and is a pandemic that continues to disrupt economic activity, social mobility and health services. The world has been hit, especially by the COVID-19 pandemic.
# 326
# If you buy something through a link on this page, we may earn a small commission. We may earn a small commission. How this works. The body does not respond to heat when a person is in hot, but a cold or flu is associated with a more severe condition. It cannot respond to heat, cold
# 282
# Coronavirus disease 2019 (COVID-19) is becoming global disease, with more than 220000 confirmed cases and more than 150 million deaths worldwide. In early 2018, the first clinical trial completed the clinical trial in the United Kingdom and China, completed which included 9,000 participants in the first cohort.
# 312

# %%
print('Number named entities, number nouns, number of sentences, avg sentence length, repeat score')
for key in length_metric_2.keys():
  metric_load = length_metric_2[key]['metric']
  print(metric_load['number_ents'], metric_load['number_nouns'],
        metric_load['number_sents'],  metric_load['avg_sent_len'],
        metric_load['sent_repeat_score'])
# Out:
# Number named entities, number nouns, number of sentences, avg sentence length, repeat score
# 1 4 3 7.0 [0.0, 0.0, 0.0]
# 2 20 4 15.5 [0.23529411764705888, 0.19999999999999996, 0.0, 0.0]
# 1 17 3 19.333333333333332 [0.0, 0.2692307692307693, 0.125]
# 1 15 3 18.0 [0.0, 0.038461538461538436, 0.08333333333333337]
# 0 10 5 12.8 [0.05555555555555558, 0.0, 0.0, 0.11111111111111116, 0.0]
# 9 13 2 27.0 [0.12, 0.3448275862068966]

# %%
for key in length_metric_3.keys():
  print(key)
  print(len(key))
# Out:
# The flu was really bad this year. Please prepare for the conference accordinly, vaccines are available. This will
# 114
# The SARS-CoV-2 virus has been identified in two countries and is spreading in a wide range of areas. With a significant number of infected people who have no significant effect from respiratory treatment, we developed a simple vaccine against SARS-CoV-2, which will be effective in preventing and transmitting SARS-CoV-2 to the general population of infected individuals. We found that this vaccine can help prevent and slow down SARS-CoV-2 infection from spreading to all areas throughout the world to prevent spreading of the virus. If we use these two doses of antiviral drugs, the epidemic is ending
# 603
# BACKGROUND: The COVID-19 pandemic is becoming increasingly public health, but many countries need to implement reasonable public health measures against COVID-19 against coronavirus disease 2019 (COVID-19) infection, particularly the development of efficient and effective vaccines and antiviral therapies. It was reported to develop several vaccines to infect coronavirus cells for this purpose and have been used in the laboratory in an extended period to combat the COVID-19 pandemic and in the laboratory of patients with COVID-19. Here, we aimed aimed to compare immunization methods used between the current generation of anti-viral and
# 642
# The coronavirus SARS-CoV-2 can cause COVID-19, leading to its death by widespread transmission worldwide. This outbreak leads to several outbreaks and deaths, most common among urban people, which are more severe in urban areas and regions. In the study, we analyzed the epidemiological parameters of COVID-19 transmission transmission among people with moderate to severe disease conditions, and found that the epidemiological parameters were less than 0.99% (95%CI: 0.96-0.98), or 0.99% (95%CI: 0.87-0.94). The prevalence of severe
# 533
# Coronavirus disease 2019 (COVID-19) is a deadly pandemic that affects more than 4 million people worldwide. For some reason, many medical organizations are now doing good research, and research into cancer and prostate cancer as the most common cancer at the study stages, suggests that cancer detection is much more accurate. In this study, we used pancreatic biopsy samples from individuals who received cancer treatment to assess risk factors for cancer development. We also investigated gene expression levels of lung cancer. Using a rapid, quantitative analysis of the seropossensitive protein E-ACE2 and C-synucleotide gene markers identified a
# 650
# The COVID-19 pandemic caused by SARS-CoV-2 has led to a global decline of economic activity and mortality. Now, a study by Phyloobiology team has identified SARS-CoV-2’s genetic origin in the body and explains how they act. The study aims to investigate the molecular mechanisms to shape the host DNA. The study first aims to predict the association between SARS-CoV-2 and human body and body fat fat (BMI), a type of fat, and the development of bone cancer. The study also examined whether genetic characteristics of the patient with severe
# 541

# %%
for key in length_metric_3.keys():
  print(length_metric_3[key]['metric'])
# Out:
# {'number_ents': 1, 'ents': [this year], 'number_nouns': 4, 'nouns': ['flu', 'year', 'conference', 'vaccine'], 'number_sents': 3, 'avg_sent_len': 7.0, 'sent_repeat_score': [0.0, 0.0, 0.0]}
# {'number_ents': 2, 'ents': [two, two], 'number_nouns': 27, 'nouns': ['SARS', 'CoV-2', 'virus', 'country', 'range', 'area', 'number', 'people', 'effect', 'treatment', 'vaccine', 'SARS', 'CoV-2', 'SARS', 'CoV-2', 'population', 'individual', 'vaccine', 'SARS', 'CoV-2', 'infection', 'area', 'world', 'virus', 'dose', 'drug', 'epidemic'], 'number_sents': 4, 'avg_sent_len': 27.5, 'sent_repeat_score': [0.09523809523809523, 0.15555555555555556, 0.1333333333333333, 0.0]}
# {'number_ents': 1, 'ents': [2019], 'number_nouns': 27, 'nouns': ['BACKGROUND', 'covid-19', 'health', 'country', 'health', 'measure', 'covid-19', 'coronavirus', 'disease', 'covid-19', 'infection', 'development', 'vaccine', 'therapy', 'vaccine', 'coronavirus', 'cell', 'purpose', 'laboratory', 'period', 'covid-19', 'laboratory', 'patient', 'covid-19', 'immunization', 'method', 'generation'], 'number_sents': 3, 'avg_sent_len': 34.0, 'sent_repeat_score': [0.18181818181818177, 0.2564102564102564, 0.052631578947368474]}
# {'number_ents': 5, 'ents': [less than, 0.99%, 0.96-0.98, 0.99%, 0.87-0.94], 'number_nouns': 25, 'nouns': ['coronavirus', 'SARS', 'CoV-2', 'covid-19', 'death', 'transmission', 'outbreak', 'outbreak', 'death', 'people', 'area', 'region', 'study', 'parameter', 'covid-19', 'transmission', 'transmission', 'people', 'disease', 'condition', 'parameter', '%', '%', 'prevalence', 'severe'], 'number_sents': 4, 'avg_sent_len': 24.75, 'sent_repeat_score': [0.0, 0.16000000000000003, 0.2692307692307693, 0.0]}
# {'number_ents': 2, 'ents': [2019, more than 4 million], 'number_nouns': 40, 'nouns': ['Coronavirus', 'disease', 'COVID-19', 'pandemic', 'people', 'reason', 'organization', 'research', 'cancer', 'prostate', 'cancer', 'cancer', 'study', 'stage', 'cancer', 'detection', 'study', 'biopsy', 'sample', 'individual', 'cancer', 'treatment', 'risk', 'factor', 'cancer', 'development', 'gene', 'expression', 'level', 'lung', 'cancer', 'analysis', 'protein', 'E', '-', 'ACE2', 'c', 'synucleotide', 'gene', 'marker'], 'number_sents': 5, 'avg_sent_len': 22.4, 'sent_repeat_score': [0.0, 0.23076923076923073, 0.04347826086956519, 0.0, 0.09523809523809523]}
# {'number_ents': 2, 'ents': [first, BMI], 'number_nouns': 35, 'nouns': ['covid-19', 'pandemic', 'SARS', 'CoV-2', 'decline', 'activity', 'mortality', 'study', 'Phyloobiology', 'team', 'SARS', 'CoV-2', 'origin', 'body', 'study', 'mechanism', 'host', 'DNA', 'study', 'association', 'SARS', 'CoV-2', 'body', 'body', 'fat', 'fat', 'BMI', 'type', 'fat', 'development', 'bone', 'cancer', 'study', 'characteristic', 'patient'], 'number_sents': 5, 'avg_sent_len': 21.0, 'sent_repeat_score': [0.0, 0.0, 0.2142857142857143, 0.2571428571428571, 0.08333333333333337]}

# %%
print('Number named entities, number nouns, number of sentences, avg sentence length, repeat score')
for key in length_metric_3.keys():
  metric_load = length_metric_3[key]['metric']
  print(metric_load['number_ents'], metric_load['number_nouns'],
        metric_load['number_sents'],  metric_load['avg_sent_len'],
        metric_load['sent_repeat_score'])
# Out:
# Number named entities, number nouns, number of sentences, avg sentence length, repeat score
# 1 4 3 7.0 [0.0, 0.0, 0.0]
# 2 27 4 27.5 [0.09523809523809523, 0.15555555555555556, 0.1333333333333333, 0.0]
# 1 27 3 34.0 [0.18181818181818177, 0.2564102564102564, 0.052631578947368474]
# 5 25 4 24.75 [0.0, 0.16000000000000003, 0.2692307692307693, 0.0]
# 2 40 5 22.4 [0.0, 0.23076923076923073, 0.04347826086956519, 0.0, 0.09523809523809523]
# 2 35 5 21.0 [0.0, 0.0, 0.2142857142857143, 0.2571428571428571, 0.08333333333333337]

# %%
#https://huggingface.co/docs/transformers/v4.16.2/en/custom_datasets

# %%
# !cp -r roberta-base-health-test-1/checkpoint-12000/ roberta-health-test-v1/

# %%
# !zip -r roberta_health_v1.zip roberta-health-test-v1/
# Out:
#   adding: roberta-health-test-v1/ (stored 0%)
#   adding: roberta-health-test-v1/checkpoint-12000/ (stored 0%)
#   adding: roberta-health-test-v1/checkpoint-12000/rng_state.pth (deflated 27%)
#   adding: roberta-health-test-v1/checkpoint-12000/pytorch_model.bin (deflated 7%)
#   adding: roberta-health-test-v1/checkpoint-12000/scheduler.pt (deflated 49%)
#   adding: roberta-health-test-v1/checkpoint-12000/trainer_state.json (deflated 82%)
#   adding: roberta-health-test-v1/checkpoint-12000/config.json (deflated 50%)
#   adding: roberta-health-test-v1/checkpoint-12000/training_args.bin (deflated 48%)
#   adding: roberta-health-test-v1/checkpoint-12000/optimizer.pt (deflated 8%)

# %%
from google.colab import files
files.download("roberta_health_v1.zip")
